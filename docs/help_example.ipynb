# %%
from exceptiongroup import catch

from tspmdb import TspmDB

try:
    my_data.close()
    del my_data
except NameError:
    pass

my_data = TspmDB("my_tspm_database.db", destructive=True)
my_data.help()
# Out:
# [HELP] Main TspmDb Object
# tspmdb = TspmDb(dbfile=str, [destructive=boolean, workers=int, max_memory_mb=int])
# ------------------------------------------------------------------------------
# tspmdb.help()         Displays this help message
# tspmdb.population     Manage/retreve data of entire population
# tspmdb.subpopulation  Operations to manage/retrieve subpopulations data
# tspmdb.dataset        Operations to manage the dataset
# tspmdb.close()        Close the dataset and release resources

# %%
dataset = my_data.dataset
dataset.help()
# Out:
# [HELP] TspmDb.Dataset Object
# TspmDb().dataset
# ------------------------------------------------------------------------------
# .help()       Displays this help message
# .clear()      Clears all data from the dataset
# .ingest()     Ingests data from CSV/ZIP+CSV files and pandas dataframes
# .calculate()  (Re)calculates all sequences and frequencies

# %%
population = my_data.population
population.help()
# Out:
# [HELP] tspmdb.Population Object
# TspmDb().population
# ------------------------------------------------------------------------------
# .help()         Displays this help message
# .identifier     The identifier representing the entire population ("ALL")
# .description    Read-only description
# .patients()     List of all patient identifiers
# .sequences()    List of calculated patient sequences
# .frequencies()  List of calculated sequences with their frequencies

# %%
my_data.subpopulation.help()
print("\n")
test_subpopulation = my_data.subpopulation.create("TEST", [], "This is a test subpopulation", destructive=True)
test_subpopulation.help()
# Out:
# [HELP] Subpopulation Operations
# TspmDb.subpopulation
# ------------------------------------------------------------------------------
# .help()                             Displays this help message
# .list()                             Lists all existing subpopulations in the database
# .get(identifier)                    Gets an existing subpopulation from the database
# .create(name, identifier, id_list)  Generates a new subpopulation in the database
#
#
# [HELP] Subpopulation Instance Operations
# TspmDb.subpopulation.get(identifier)
# ------------------------------------------------------------------------------
#  .help()                                Displays this help message
#  .patients.list()                       List of patients in the subpopulation
#  .patients.add()                        Add a patient to the subpopulation
#  .patients.remove()                     Remove a patient from the subpopulation
# ...
